# %%
print("Hello python world!!")
print("notebook is useful")
# Out:
# Hello python world!!
# notebook is useful

# %% [markdown]
# #간단한 출력문

# %%
msg = input("메시지 입력 : ")
print("당신이 입력한 메시지는")
print(msg)
print("입니다.")
